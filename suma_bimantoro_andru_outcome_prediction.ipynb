# %% [markdown]
# # 1 - Name

# %% [markdown]
# Name:Suma Bimantoro Andru
#
# Dataset: Diabetes
#
# Objective:<b>model Classification outcome Prediction </b>

# %% [markdown]
# # 2 - Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,ConfusionMatrixDisplay,confusion_matrix
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.compose import ColumnTransformer

# %% [markdown]
# # 3 - Data Loading

# %%
# Load Dataset

data = pd.read_csv('/content/diabetes.csv')

# %%
#Tampilkan Head
data.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1

# %%
#Tampilkan Tail
data.tail(3)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
# Duplicate Dataset

data_copy = data.copy()

# %%
#tampilkan informasi untuk melihat field
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# <p>In this dataset there are <b>9</b> columns and <b>768</b> rows, all data types are <b>numeric</b></p>

# %%
#check dataset
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# <p>It can be seen from the <b>median</b> value is <b>29</b>, which means that many <b>ages 29</b> and the youngest age is <b>21</b>< /p>

# %% [markdown]
# <h1><b>C-MAP</b></h1>

# %%
#melihat corelasi dengan c-map
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

#Correlation Between Numeric Columns
corr = data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e8f50_row0_col0, #T_e8f50_row1_col1, #T_e8f50_row2_col2, #T_e8f50_row3_col3, #T_e8f50_row4_col4, #T_e8f50_row5_col5, #T_e8f50_row6_col6, #T_e8f50_row7_col7, #T_e8f50_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e8f50_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_e8f50_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_e8f50_row0_col3, #T_e8f50_row7_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_e8f50_row0_col4, #T_e8f50_row0_col5, #T_e8f50_row0_col6, #T_e8f50_row2_col8, #T_e8f50_row3_col0, #T_e8f50_row3_col1, #T_e8f50_row3_col7, #T_e8f50_row6_col2, #T_e8f50_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e8f50_row0_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_e8f50_row0_col8, #T_e8f50_row1_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e8f50_row1_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_e8f50_row1_col2, #T_e8f50_row6_col8 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_e8f50_row1_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_e8f50_row1_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_e8f50_row1_col5, #T_e8f50_row3_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_e8f50_row1_col7 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_e8f50_row1_col8 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_e8f50_row2_col0, #T_e8f50_row7_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_e8f50_row2_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_e8f50_row2_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_e8f50_row2_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_e8f50_row2_col5, #T_e8f50_row6_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_e8f50_row2_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_e8f50_row2_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_e8f50_row3_col2, #T_e8f50_row5_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_e8f50_row3_col4 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_e8f50_row3_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_e8f50_row3_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e8f50_row4_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_e8f50_row4_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_e8f50_row4_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_e8f50_row4_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_e8f50_row4_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_e8f50_row4_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_e8f50_row4_col7, #T_e8f50_row7_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_e8f50_row4_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_e8f50_row5_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_e8f50_row5_col2, #T_e8f50_row5_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_e8f50_row5_col3 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_e8f50_row5_col6, #T_e8f50_row8_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_e8f50_row5_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_e8f50_row5_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e8f50_row6_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_e8f50_row6_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_e8f50_row6_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_e8f50_row6_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_e8f50_row6_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_e8f50_row7_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_e8f50_row7_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_e8f50_row7_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_e8f50_row7_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_e8f50_row8_col0, #T_e8f50_row8_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_e8f50_row8_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_e8f50_row8_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e8f50_row8_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_e8f50_row8_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_e8f50_row8_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# </style>
# <table id="T_e8f50_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Pregnancies</th>
#       <th class="col_heading level0 col1" >Glucose</th>
#       <th class="col_heading level0 col2" >BloodPressure</th>
#       <th class="col_heading level0 col3" >SkinThickness</th>
#       <th class="col_heading level0 col4" >Insulin</th>
#       <th class="col_heading level0 col5" >BMI</th>
#       <th class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th class="col_heading level0 col7" >Age</th>
#       <th class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8f50_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_e8f50_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e8f50_row0_col1" class="data row0 col1" >0.129459</td>
#       <td id="T_e8f50_row0_col2" class="data row0 col2" >0.141282</td>
#       <td id="T_e8f50_row0_col3" class="data row0 col3" >-0.081672</td>
#       <td id="T_e8f50_row0_col4" class="data row0 col4" >-0.073535</td>
#       <td id="T_e8f50_row0_col5" class="data row0 col5" >0.017683</td>
#       <td id="T_e8f50_row0_col6" class="data row0 col6" >-0.033523</td>
#       <td id="T_e8f50_row0_col7" class="data row0 col7" >0.544341</td>
#       <td id="T_e8f50_row0_col8" class="data row0 col8" >0.221898</td>
#     </tr>
#     <tr>
#       <th id="T_e8f50_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_e8f50_row1_col0" class="data row1 col0" >0.129459</td>
#       <td id="T_e8f50_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e8f50_row1_col2" class="data row1 col2" >0.152590</td>
#       <td id="T_e8f50_row1_col3" class="data row1 col3" >0.057328</td>
#       <td id="T_e8f50_row1_col4" class="data row1 col4" >0.331357</td>
#       <td id="T_e8f50_row1_col5" class="data row1 col5" >0.221071</td>
#       <td id="T_e8f50_row1_col6" class="data row1 col6" >0.137337</td>
#       <td id="T_e8f50_row1_col7" class="data row1 col7" >0.263514</td>
#       <td id="T_e8f50_row1_col8" class="data row1 col8" >0.466581</td>
#     </tr>
#     <tr>
#       <th id="T_e8f50_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_e8f50_row2_col0" class="data row2 col0" >0.141282</td>
#       <td id="T_e8f50_row2_col1" class="data row2 col1" >0.152590</td>
#       <td id="T_e8f50_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e8f50_row2_col3" class="data row2 col3" >0.207371</td>
#       <td id="T_e8f50_row2_col4" class="data row2 col4" >0.088933</td>
#       <td id="T_e8f50_row2_col5" class="data row2 col5" >0.281805</td>
#       <td id="T_e8f50_row2_col6" class="data row2 col6" >0.041265</td>
#       <td id="T_e8f50_row2_col7" class="data row2 col7" >0.239528</td>
#       <td id="T_e8f50_row2_col8" class="data row2 col8" >0.065068</td>
#     </tr>
#     <tr>
#       <th id="T_e8f50_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_e8f50_row3_col0" class="data row3 col0" >-0.081672</td>
#       <td id="T_e8f50_row3_col1" class="data row3 col1" >0.057328</td>
#       <td id="T_e8f50_row3_col2" class="data row3 col2" >0.207371</td>
#       <td id="T_e8f50_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_e8f50_row3_col4" class="data row3 col4" >0.436783</td>
#       <td id="T_e8f50_row3_col5" class="data row3 col5" >0.392573</td>
#       <td id="T_e8f50_row3_col6" class="data row3 col6" >0.183928</td>
#       <td id="T_e8f50_row3_col7" class="data row3 col7" >-0.113970</td>
#       <td id="T_e8f50_row3_col8" class="data row3 col8" >0.074752</td>
#     </tr>
#     <tr

# %% [markdown]
# <p>Seeing the correlation, it is the same as the researcher's visualization of death above at the time of data introduction,
# The following features will be selected later.</p>
# <li> Pregnancies
# <li> Glucose
# <li> Insulin
# <li> BMI
# <li> DiabetesPedigreeFunction
# <li> Age

# %% [markdown]
# # 5 - Data Preprocessing

# %% [markdown]
# This section contains the process of preparing data for the model training process, such as dividing data into train-dev-test, data transformation (normalization, encoding, etc.), and other processes needed.

# %% [markdown]
# ## Get data for model inference

# %%
## Get data for model inference
data_inf = data.sample(20, random_state=17)
data_inf
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 649            0      107             60             25        0  26.4
# 516            9      145             88             34      165  30.3
# 151            4      114             65              0        0  21.9
# 381            0      105             68             22        0  20.0
# 325            1      157             72             21      168  25.6
# 473            7      136             90              0        0  29.9
# 736            0      126             86             27      120  27.4
# 300            0      167              0              0        0  32.3
# 662            8      167            106             46      231  37.6
# 484            0      145              0              0        0  44.2
# 495            6      166             74              0        0  26.6
# 590           11      111             84             40        0  46.8
# 610            3      106             54             21      158  30.9
# 358           12       88             74             40       54  35.3
# 382            1      109             60              8      182  25.4
# 448            0      104             64             37       64  33.6
# 586            8      143             66              0        0  34.9
# 566            1       99             72             30       18  38.6
# 333           12      106             80              0        0  23.6
# 165            6      104             74             18      156  29.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 649                     0.133   23        0
# 516                     0.771   53        1
# 151                     0.432   37        0
# 381                     0.236   22        0
# 325                     0.123   24        0
# 473                     0.210   50        0
# 736                     0.515   21        0
# 300                     0.839   30        1
# 662                     0.165   43        1
# 484                     0.630   31        1
# 495                     0.304   66        0
# 590                     0.925   45        1
# 610                     0.292   24        0
# 358                     0.378   48        0
# 382                     0.947   21        0
# 448                     0.510   22        1
# 586                     0.129   41        1
# 566                     0.412   21        0
# 333                     0.137   44        0
# 165                     0.722   41        1

# %%
# remove inference set from data set
data_train_test = data.drop(data_inf.index)
data_train_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [748 rows x 9 columns]

# %%
#reset index to reduce error
data_train_test.reset_index(drop= True, inplace=True)
data_inf.reset_index(drop=True, inplace=True)
data_inf
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             0      107             60             25        0  26.4
# 1             9      145             88             34      165  30.3
# 2             4      114             65              0        0  21.9
# 3             0      105             68             22        0  20.0
# 4             1      157             72             21      168  25.6
# 5             7      136             90              0        0  29.9
# 6             0      126             86             27      120  27.4
# 7             0      167              0              0        0  32.3
# 8             8      167            106             46      231  37.6
# 9             0      145              0              0        0  44.2
# 10            6      166             74              0        0  26.6
# 11           11      111             84             40        0  46.8
# 12            3      106             54             21      158  30.9
# 13           12       88             74             40       54  35.3
# 14            1      109             60              8      182  25.4
# 15            0      104             64             37       64  33.6
# 16            8      143             66              0        0  34.9
# 17            1       99             72             30       18  38.6
# 18           12      106             80              0        0  23.6
# 19            6      104             74             18      156  29.9
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.133   23        0
# 1                      0.771   53        1
# 2                      0.432   37        0
# 3                      0.236   22        0
# 4                      0.123   24        0
# 5                      0.210   50        0
# 6                      0.515   21        0
# 7                      0.839   30        1
# 8                      0.165   43        1
# 9                      0.630   31        1
# 10                     0.304   66        0
# 11                     0.925   45        1
# 12                     0.292   24        0
# 13                     0.378   48        0
# 14                     0.947   21        0
# 15                     0.510   22        1
# 16                     0.129   41        1
# 17                     0.412   21        0
# 18                     0.137   44        0
# 19                     0.722   41        1

# %% [markdown]
# ## Splitting between `X` (Features) and `y` (Target)

# %%
# Split between `X` (Features) and `y` (Target)

X = data_train_test.drop('Outcome', axis=1)
y = data_train_test['Outcome']
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 743           10      101             76             48      180  32.9
# 744            2      122             70             27        0  36.8
# 745            5      121             72             23      112  26.2
# 746            1      126             60              0        0  30.1
# 747            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 743                     0.171   63
# 744                     0.340   27
# 745                     0.245   30
# 746                     0.349   47
# 747                     0.315   23
#
# [748 rows x 8 columns]

# %%
# Split between Train-Set and Test-Set 80% dan 20%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=17)

print('Train Size : ', X_train.shape)
print('Test Size  : ', X_test.shape)
# Out:
# Train Size :  (598, 8)
# Test Size  :  (150, 8)

# %% [markdown]
# ## Handling outliers

# %%
#membuat fungsi IQR untuk deteksi outlier, dipakai jika data itu skew
def find_skewed_boundaries(df, variable, distance):
    IQR = df[variable].quantile(0.75) - df[variable].quantile(0.25)

    lower_boundary = df[variable].quantile(0.25) - (IQR * distance)
    upper_boundary = df[variable].quantile(0.75) + (IQR * distance)

    return upper_boundary, lower_boundary

# %%
#membuat fungsi untuk deteksi outlier, dipakai jika data itu tidak skew atau distribusi normal
def find_normal_boundaries(X_train, variable):
    upper_boundary = X_train[variable].mean() + 3 * X_train[variable].std()
    lower_boundary = X_train[variable].mean() - 3 * X_train[variable].std()

    return upper_boundary, lower_boundary

# %% [markdown]
# <b><h1>Pregnancies</h1></b>

# %%
#Cek Skew
data['Pregnancies'].skew()
# Out:
# 0.9016739791518588

# %% [markdown]
# skew

# %% [markdown]
# <b><h1>Glucose</h1></b>

# %%
data['Glucose'].skew()
# Out:
# 0.17375350179188992

# %% [markdown]
# not skew

# %% [markdown]
# <b><h1>Insulin</h1></b>

# %%
#Cek Skew
data['Insulin'].skew()
# Out:
# 2.272250858431574

# %% [markdown]
# skew

# %% [markdown]
# <b><h1>BMI</h1></b>

# %%
#Cek Skew
data['BMI'].skew()
# Out:
# -0.42898158845356543

# %% [markdown]
# not skew

# %% [markdown]
# DiabetesPedigreeFunction

# %%
#Cek Skew
data['DiabetesPedigreeFunction'].skew()
# Out:
# 1.919911066307204

# %% [markdown]
# skew

# %% [markdown]
# Age

# %%
#Cek Skew
data['Age'].skew()
# Out:
# 1.1295967011444805

# %% [markdown]
# skew

# %% [markdown]
# ## Handling missing Value

# %%
# Check Missing Values in `X_train`
X_train.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
# Check Missing Values in `X_test`

X_test.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
# Check Missing Values in `y_train`

y_train.isnull().sum()
# Out:
# 0

# %%
# Check Missing Values in `y_test`

y_test.isna().sum()
# Out:
# 0

# %% [markdown]
# <b><h1>There is no missing value in X or y</h1></b>

# %% [markdown]
# ## Feature Selection

# %%
#display Xtrain
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 644            9      145             80             46      130  37.9
# 418            0       94              0              0        0   0.0
# 565            2      197             70             99        0  34.7
# 48             7      103             66             32        0  39.1
# 201            2       99             70             16       44  20.4
# ..           ...      ...            ...            ...      ...   ...
# 406            0      138             60             35      167  34.6
# 390            3       82             70              0        0  21.1
# 143           10      108             66              0        0  32.4
# 241            6      119             50             22      176  27.1
# 623            0      102             86             17      105  29.3
#
#      DiabetesPedigreeFunction  Age
# 644                     0.637   40
# 418                     0.256   25
# 565                     0.575   62
# 48                      0.344   31
# 201                     0.235   27
# ..                        ...  ...
# 406                     0.534   21
# 390                     0.389   25
# 143                     0.272   42
# 241                     1.318   33
# 623                     0.695   27
#
# [598 rows x 8 columns]

# %%
# membuat df bedasarkan Feature selection

X_train_new=X_train[['Pregnancies','Glucose','Insulin','BMI','DiabetesPedigreeFunction','Age']]
X_test_new=X_test[['Pregnancies','Glucose','Insulin','BMI','DiabetesPedigreeFunction','Age']]
X_train_new
# Out:
#      Pregnancies  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age
# 644            9      145      130  37.9                     0.637   40
# 418            0       94        0   0.0                     0.256   25
# 565            2      197        0  34.7                     0.575   62
# 48             7      103        0  39.1                     0.344   31
# 201            2       99       44  20.4                     0.235   27
# ..           ...      ...      ...   ...                       ...  ...
# 406            0      138      167  34.6                     0.534   21
# 390            3       82        0  21.1                     0.389   25
# 143           10      108        0  32.4                     0.272   42
# 241            6      119      176  27.1                     1.318   33
# 623            0      102      105  29.3                     0.695   27
#
# [598 rows x 6 columns]

# %%
# Get Numerical Columns and Categorical Columns

num_columns = X_train.select_dtypes(include=np.number).columns.tolist()
cat_columns = X_train.select_dtypes(include=['object']).columns.tolist()

print('Numerical Columns : ', num_columns)
print('Categorical Columns : ', cat_columns)
# Out:
# Numerical Columns :  ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
# Categorical Columns :  []

# %% [markdown]
# ## Pipeline

# %%
#divide num by skew and normal, cat by ordinal and none
num_normal = ['Glucose','BMI']
num_skew = ['Pregnancies','Insulin','DiabetesPedigreeFunction','Age']

# %%
#persiapkan column transformer untuk membedakan proses per kolom
preprocess = ColumnTransformer([
    ('numnormal', StandardScaler(),num_normal),
    ('numskew', MinMaxScaler(),num_skew)
  ])

# %%
# Fit and Transform

X_train_pipline = preprocess.fit_transform(X_train)
X_test_pipline = preprocess.transform(X_test)
X_train_pipline.shape
# Out:
# (598, 6)

# %% [markdown]
# # 6 - Model Definition

# %%
#mendefinisikan model

ranfor= RandomForestClassifier()

# %% [markdown]
# # 7 - Model Training

# %%
#Random Forest
# %timeit ranfor.fit(X_train_pipline, y_train)
# Out:
# 177 ms ± 9.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# # 8 - Model Evaluation

# %% [markdown]
# researchers will do with the validation score and accuracy

# %% [markdown]
# ##Random Forest

# %%
#Define variable untuk memakai Cross_val_score
scores_ranfor = cross_val_score(ranfor, X_train_pipline, y_train,cv=5)

# %%
#memakai method mean() untuk mencari mean
scores_ranfor.mean()
# Out:
# 0.7642156862745098

# %%
#memakai method std() untuk mencari std
scores_ranfor.std()
# Out:
# 0.014294499413324965

# %% [markdown]
# ##<b><h1>Scoring Results</h1></b>

# %%
#define variable dan melakukan predict bagi data test dan data train


#RandomForestClassifier()
y_pred_train_ranfor = ranfor.predict(X_train_pipline)
y_pred_test_ranfor = ranfor.predict(X_test_pipline)

# %%
#Menampilkan acc_score di semua model algoritma yang sudah kita definisikan
print('-----TRAIN-----')

print('accuracy score train RandomForestClassifier : ',accuracy_score(y_train,y_pred_train_ranfor))


print('-----TEST-----')

print('accuracy score train RandomForestClassifier : ',accuracy_score(y_test,y_pred_test_ranfor))
# Out:
# -----TRAIN-----
# accuracy score train RandomForestClassifier :  1.0
# -----TEST-----
# accuracy score train RandomForestClassifier :  0.76

# %%
print('')
print (f'Model Random Forest Mean :{scores_ranfor.mean()}')
print (f'Model Random Forest STD :{scores_ranfor.std()}')
# Out:
# Model Random Forest Mean :0.7642156862745098
# Model Random Forest STD :0.014294499413324965

# %% [markdown]
# the validation score here is set cv=5 which means check at 5 metrics

# %%
#y_train predict randfor
cm = confusion_matrix(y_train, y_pred_train_ranfor, labels=ranfor.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=ranfor.classes_)

disp.plot()
plt.show()

# %% [markdown]
# - From the analysis above, it is found that y_train makes perfect predictions where there are no errors

# %%
#randfor
print(classification_report(y_train,y_pred_train_ranfor))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       384
#            1       1.00      1.00      1.00       214
#
#     accuracy                           1.00       598
#    macro avg       1.00      1.00      1.00       598
# weighted avg       1.00      1.00      1.00       598

# %% [markdown]
# ##Hyperparameter assignment

# %%
#define dari parameter manual
ranfortuning= RandomForestClassifier(n_estimators=86, max_depth=18)

# %%
#make a fit
ranfortuning.fit(X, y)
# Out:
# RandomForestClassifier(max_depth=18, n_estimators=86)

# %% [markdown]
# random forest after tuning

# %%
#validation score setelah model di tuning
scores_ranfortuning = cross_val_score(ranfortuning, X_train_pipline, y_train,cv=5)

# %%
#melihat mean dari hasil validation model setelah di tuning
scores_ranfortuning.mean()
# Out:
# 0.749187675070028

# %%
#melihat std dari hasil validation model setelah di tuning
scores_ranfortuning.std()
# Out:
# 0.020149267615212876

# %% [markdown]
# #9-Model Inference

# %%
#reset index data inference
data_inf = data_inf.reset_index(drop=True)
data_inf
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             0      107             60             25        0  26.4
# 1             9      145             88             34      165  30.3
# 2             4      114             65              0        0  21.9
# 3             0      105             68             22        0  20.0
# 4             1      157             72             21      168  25.6
# 5             7      136             90              0        0  29.9
# 6             0      126             86             27      120  27.4
# 7             0      167              0              0        0  32.3
# 8             8      167            106             46      231  37.6
# 9             0      145              0              0        0  44.2
# 10            6      166             74              0        0  26.6
# 11           11      111             84             40        0  46.8
# 12            3      106             54             21      158  30.9
# 13           12       88             74             40       54  35.3
# 14            1      109             60              8      182  25.4
# 15            0      104             64             37       64  33.6
# 16            8      143             66              0        0  34.9
# 17            1       99             72             30       18  38.6
# 18           12      106             80              0        0  23.6
# 19            6      104             74             18      156  29.9
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.133   23        0
# 1                      0.771   53        1
# 2                      0.432   37        0
# 3                      0.236   22        0
# 4                      0.123   24        0
# 5                      0.210   50        0
# 6                      0.515   21        0
# 7                      0.839   30        1
# 8                      0.165   43        1
# 9                      0.630   31        1
# 10                     0.304   66        0
# 11                     0.925   45        1
# 12                     0.292   24        0
# 13                     0.378   48        0
# 14                     0.947   21        0
# 15                     0.510   22        1
# 16                     0.129   41        1
# 17                     0.412   21        0
# 18                     0.137   44        0
# 19                     0.722   41        1

# %% [markdown]
# ##Inference Preprocessing

# %%
# Split Numerical and Categorical Features
inference_num = data_inf[num_cols]
inference_cat = data_inf[cat_cols]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-bfa00b69fd2a> in <module>
#       1 # Split Numerical and Categorical Features
# ----> 2 inference_num = data_inf[num_cols]
#       3 inference_cat = data_inf[cat_cols]
#
# NameError: name 'num_cols' is not defined

# %%
inference_final = preprocess.fit_transform(data_inf)

# %% [markdown]
# ##Predicition

# %%
y_pred_inf = ranfor.predict(inference_final)

# %%
#rubah ke dataframe
y_pred_inf = pd.DataFrame(y_pred_inf, columns=['random forest'])

# %%
#Buat dataframe prediction
predictions = pd.concat([data_inf['Outcome'], y_pred_inf], axis=1)
predictions.columns = ['Actual','prediction']
predictions

# %% [markdown]
# Miss one from 20 data inference
